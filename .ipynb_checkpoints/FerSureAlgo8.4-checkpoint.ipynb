# %%
import csv
import pandas as pd
from datetime import datetime


MAINDIR = "./"

# Read and Prepare Tables
atp2022 = pd.read_csv('Data/atp_matches_2022.csv', encoding = 'UTF-8')
challenger2022 = pd.read_csv('Data/atp_matches_qual_chall_2022.csv', encoding = 'UTF-8')
Futures2022 = pd.read_csv('Data/atp_matches_futures_2022.csv', encoding = 'UTF-8')

atp2022 = pd.DataFrame(atp2022)
challenger2022 = pd.DataFrame(challenger2022)
futures2022 = pd.DataFrame(Futures2022)

allMatches = pd.concat([atp2022, challenger2022, futures2022])


player = input().title()

# Collecting Wins from Inputed Player
resultW = allMatches.loc[allMatches["winner_name"] == player, ["loser_name", "loser_rank", 'score', 'tourney_date','loser_ioc']]
# Formatting Table
resultW = resultW.reset_index(drop = True)
resultW = pd.DataFrame(resultW)
resultW[['tourney_date']] = resultW[['tourney_date']].applymap(str).applymap(lambda s: "{}/{}/{}".format(s[4:6],s[6:], s[0:4]))
resultW.columns = ['Opp_Name', 'Opp_Ranking', 'Score', 'Date', 'Nationality']

# Collecting Wins Stats
countW = len(resultW)
avgOppRankW = int(resultW["Opp_Ranking"].mean(skipna=True))

# Analyzing Wins by Ranking Buckets
wins_b_1_5 = resultW.apply(lambda x : True
        if x['Opp_Ranking'] <= 1 and x['Opp_Ranking'] <= 5 else False, axis = 1)
num_wins_b_1_5 = len(wins_b_1_5[wins_b_1_5 == True].index)

wins_b_5_10 = resultW.apply(lambda x : True
        if x['Opp_Ranking'] <= 5 and x['Opp_Ranking'] <= 10 else False, axis = 1)
num_wins_b_5_10 = len(wins_b_5_10[wins_b_5_10 == True].index)

wins_b_10_15 = resultW.apply(lambda x : True
        if x['Opp_Ranking'] <= 10 and x['Opp_Ranking'] <= 15 else False, axis = 1)
num_wins_b_10_15 = len(wins_b_10_15[wins_b_10_15 == True].index)

wins_b_15_25 = resultW.apply(lambda x : True
        if x['Opp_Ranking'] <= 15 and x['Opp_Ranking'] <= 25 else False, axis = 1)
num_wins_b_15_25 = len(wins_b_15_25[wins_b_15_25 == True].index)

wins_b_25_50 = resultW.apply(lambda x : True
        if x['Opp_Ranking'] <= 25 and x['Opp_Ranking'] <= 50 else False, axis = 1)
num_wins_b_25_50 = len(wins_b_25_50[wins_b_25_50 == True].index)

wins_b_50_75 = resultW.apply(lambda x : True
        if x['Opp_Ranking'] <= 50 and x['Opp_Ranking'] <= 75 else False, axis = 1)
num_wins_b_50_75 = len(wins_b_50_75[wins_b_50_75 == True].index)

wins_b_75_100 = resultW.apply(lambda x : True
        if x['Opp_Ranking'] <= 75 and x['Opp_Ranking'] <= 100 else False, axis = 1)
num_wins_b_75_100 = len(wins_b_75_100[wins_b_75_100 == True].index)

wins_b_100_150 = resultW.apply(lambda x : True
        if x['Opp_Ranking'] <= 100 and x['Opp_Ranking'] <= 150 else False, axis = 1)
num_wins_b_100_150 = len(wins_b_100_150[wins_b_100_150 == True].index)

wins_b_150_200 = resultW.apply(lambda x : True
        if x['Opp_Ranking'] <= 150 and x['Opp_Ranking'] <= 200 else False, axis = 1)
num_wins_b_150_200 = len(wins_b_150_200[wins_b_150_200 == True].index)

wins_b_200_300 = resultW.apply(lambda x : True
            if x['Opp_Ranking'] <= 200 and x['Opp_Ranking'] <= 300 else False, axis = 1)
num_wins_b_200_300 = len(wins_b_200_300[wins_b_200_300 == True].index)

wins_b_300_400 = resultW.apply(lambda x : True
            if x['Opp_Ranking'] <= 300 and x['Opp_Ranking'] <= 400 else False, axis = 1)
num_wins_b_300_400 = len(wins_b_300_400[wins_b_300_400 == True].index)

wins_b_400_500 = resultW.apply(lambda x : True
            if x['Opp_Ranking'] <= 400 and x['Opp_Ranking'] <= 500 else False, axis = 1)
num_wins_b_400_500 = len(wins_b_400_500[wins_b_400_500 == True].index)

wins_b_500_600 = resultW.apply(lambda x : True
            if x['Opp_Ranking'] <= 500 and x['Opp_Ranking'] <= 600 else False, axis = 1)
num_wins_b_500_600 = len(wins_b_500_600[wins_b_500_600 == True].index)

wins_b_600_700 = resultW.apply(lambda x : True
            if x['Opp_Ranking'] >= 600 and x['Opp_Ranking'] <= 700 else False, axis = 1)
num_wins_b_600_700 = len(wins_b_600_700[wins_b_600_700 == True].index)

wins_b_700_800 = resultW.apply(lambda x : True
            if x['Opp_Ranking'] >= 700 and x['Opp_Ranking'] <= 800 else False, axis = 1)
num_wins_b_700_800 = len(wins_b_700_800[wins_b_700_800 == True].index)

wins_b_800_900 = resultW.apply(lambda x : True
            if x['Opp_Ranking'] >= 800 and x['Opp_Ranking'] <= 900 else False, axis = 1)
num_wins_b_800_900 = len(wins_b_800_900[wins_b_800_900 == True].index)

wins_b_900_1000 = resultW.apply(lambda x : True
            if x['Opp_Ranking'] >= 900 and x['Opp_Ranking'] <= 1000 else False, axis = 1)
num_wins_b_900_1000 = len(wins_b_900_1000[wins_b_900_1000 == True].index)

wins_b_1000_1100 = resultW.apply(lambda x : True
            if x['Opp_Ranking'] >= 1000 and x['Opp_Ranking'] <= 1100 else False, axis = 1)
num_wins_b_1000_1100 = len(wins_b_1000_1100[wins_b_1000_1100 == True].index)

wins_b_1100_1200 = resultW.apply(lambda x : True
            if x['Opp_Ranking'] >= 1100 and x['Opp_Ranking'] <= 1200 else False, axis = 1)
num_wins_b_1100_1200 = len(wins_b_1100_1200[wins_b_1100_1200 == True].index)

wins_b_1200_1300 = resultW.apply(lambda x : True
            if x['Opp_Ranking'] >= 1200 and x['Opp_Ranking'] <= 1300 else False, axis = 1)
num_wins_b_1200_1300 = len(wins_b_1200_1300[wins_b_1200_1300 == True].index)

wins_b_1300_1400 = resultW.apply(lambda x : True
            if x['Opp_Ranking'] >= 1300 and x['Opp_Ranking'] <= 1400 else False, axis = 1)
num_wins_b_1300_1400 = len(wins_b_1300_1400[wins_b_1300_1400 == True].index)

wins_b_1400_1500 = resultW.apply(lambda x : True
            if x['Opp_Ranking'] >= 1400 and x['Opp_Ranking'] <= 1500 else False, axis = 1)
num_wins_b_1400_1500 = len(wins_b_1400_1500[wins_b_1400_1500 == True].index)

# Method that Analysis each Player in loser_column of the ResultsW Table (In other words, looking into every player our current PLAYER has beat)

# def so_Who_You_Been_Beating_Eh(table, table_row):
    
    



# Assign Points
score = (num_wins_b_1_5 * 50) + (num_wins_b_5_10 * 40) + (num_wins_b_10_15 * 30) + (num_wins_b_15_25 * 25) + (num_wins_b_25_50 * 15) + (num_wins_b_50_75 * 10) + (num_wins_b_75_100 * 7) + (num_wins_b_100_150 * 5) + (num_wins_b_150_200 * 4) + (num_wins_b_200_300 * 3) + (num_wins_b_300_400 * 2) + (num_wins_b_400_500 * 1.9) + (num_wins_b_500_600 * 1.8) + (num_wins_b_600_700 * 1.7) + (num_wins_b_700_800 * 1.6) + (num_wins_b_800_900 * 1.5) + (num_wins_b_900_1000 * 1.4) + (num_wins_b_1000_1100 * 1.3) + (num_wins_b_1100_1200 * 1.2) + (num_wins_b_1200_1300 * 1.1) + (num_wins_b_1300_1400 * 1.05) + (num_wins_b_1400_1500 * 1)

# Collecting top 500 wins
# def top_500_wins(ranking):
#     if ranking

# --------------------------------------------------------------------------------------
# Collecting Losses from Inputed Player
resultL = allMatches.loc[allMatches["loser_name"] == player, ["winner_name", "winner_rank", 'score', 'tourney_date', 'winner_ioc']]
# Formatting Table
resultL = resultL.reset_index(drop = True)
resultL = pd.DataFrame(resultL)
resultL[['tourney_date']] = resultL[['tourney_date']].applymap(str).applymap(lambda s: "{}/{}/{}".format(s[4:6],s[6:], s[0:4]))
resultL.columns = ['Opp_Name', 'Opp_Ranking', 'Score', 'Date', 'Nationality']
# Collecting Loss Stats
countL = len(resultL)
avgOppRankL = int(resultL["Opp_Ranking"].mean(skipna=True))
record = 'W-L Record' + ':' + str(countW) + '-' + str(countL)


# print(player + "'s" + " " + "Wins")
# print(resultW)
# print("-------------------------------------------------------------------")
# print(player + "'s" + " " + "Losses")
# print(resultL)
print("-------------------------------------------------------------------")
print(record)
print("-------------------------------------------------------------------")
print("Avg. Opponent Rank (Wins):" + " " + str(avgOppRankW))
print("Avg. Opponent Rank (Losses):" + " " + str(avgOppRankL))
print("-------------------------------------------------------------------")
print(player + "'s " + 'FerSure Score is: ' + str(int(score)))
# Out:
# Nathan Ponwith
# -------------------------------------------------------------------
# W-L Record:21-17
# -------------------------------------------------------------------
# Avg. Opponent Rank (Wins): 1125
# Avg. Opponent Rank (Losses): 719
# -------------------------------------------------------------------
# Nathan Ponwith's FerSure Score is: 16
